# %% [markdown]
# import the necesary library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Read the data

# %%
data = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Baseball/baseball.csv')
data
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# This dataset contains the details of baseball case study in which numeriacl data is present. Here 'W' is our target/output veriable W mins No. of wins which contains numerical so it will be termed as a regression problem where we need to predict the several No. of wins using the regression problem.

# %% [markdown]
# # Exploratory data analysis (EDA)

# %%
# check the dimension of the dataset
data.shape
# Out:
# (30, 17)

# %% [markdown]
# This dataset contains 30 rows and 17 columns. out of which 1 target variable and remaining 16 are independent variables

# %%
# check the columns of the dataset 
data.columns.tolist()
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %%
# check the NO. of wins unique values in the dataset 
data['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
# changing the name of the columns 

data.rename(columns={'W':'Wins',\
                    'R':'Runs scored',\
                    'AB':'At bat or time at bat',\
                    'H':'base hit',\
                    '2B':'second base',\
                    '3B':'Triple',\
                    'HR':'Home runs',\
                    'BB':'Base on balls',\
                    'SO':'Strikeout',\
                    'SB':'Stolen base',\
                    'RA':'Run Average',\
                    'ER':'Earned run',\
                    'ERA':'Earned Run Average',\
                    'CG':'Complete Game',\
                    'SHO':'Shutout',\
                    'SV':'Save',\
                    'E':'Errors'},\
           inplace=True)

# %% [markdown]
# Here we change the name and make the proper name in column

# %%
data
# Out:
#     Wins  Runs scored  At bat or time at bat  base hit  second base  Triple  \
# 0     95          724                   5575      1497          300      42
# 1     83          696                   5467      1349          277      44
# 2     81          669                   5439      1395          303      29
# 3     76          622                   5533      1381          260      27
# 4     74          689                   5605      1515          289      49
# 5     93          891                   5509      1480          308      17
# 6     87          764                   5567      1397          272      19
# 7     81          713                   5485      1370          246      20
# 8     80          644                   5485      1383          278      32
# 9     78          748                   5640      1495          294      33
# 10    88          751                   5511      1419          279      32
# ...

# %%
# check the data types of columns 
data.dtypes
# Out:
# Wins                       int64
# Runs scored                int64
# At bat or time at bat      int64
# base hit                   int64
# second base                int64
# Triple                     int64
# Home runs                  int64
# Base on balls              int64
# Strikeout                  int64
# Stolen base                int64
# Run Average                int64
# Earned run                 int64
# Earned Run Average       float64
# Complete Game              int64
# Shutout                    int64
# Save                       int64
# Errors                     int64
# dtype: object

# %% [markdown]
# Here all data type is int64 only Earned run average is float data type

# %%
# checking the null values 
data.isnull().sum()
# Out:
# Wins                     0
# Runs scored              0
# At bat or time at bat    0
# base hit                 0
# second base              0
# Triple                   0
# Home runs                0
# Base on balls            0
# Strikeout                0
# Stolen base              0
# Run Average              0
# Earned run               0
# Earned Run Average       0
# Complete Game            0
# Shutout                  0
# Save                     0
# Errors                   0
# dtype: int64

# %% [markdown]
# There is no null value present in the data set

# %%
# check the info about the data 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Wins                   30 non-null     int64
#  1   Runs scored            30 non-null     int64
#  2   At bat or time at bat  30 non-null     int64
#  3   base hit               30 non-null     int64
#  4   second base            30 non-null     int64
#  5   Triple                 30 non-null     int64
#  6   Home runs              30 non-null     int64
#  7   Base on balls          30 non-null     int64
#  8   Strikeout              30 non-null     int64
#  9   Stolen base            30 non-null     int64
#  10  Run Average            30 non-null     int64
#  11  Earned run             30 non-null     int64
#  12  Earned Run Average     30 non-null     float64
#  13  Complete Game          30 non-null     int64
#  14  Shutout                30 non-null     int64
# ...

# %%
# visualize null using heatmap
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Check the null value using heat map only see one color that means no missing data present in this dataset

# %%
# checking the value counts of each columns 
for i in data.columns:
    print(data[i].value_counts())
    print('\n')
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: Wins, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: Runs scored, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %% [markdown]
# There are the value counts of all columns and we can see all columns very good

# %%
# check the categarical and numerical columns
categorical_col = []
for i in data.dtypes.index:
    if data.dtypes[i] == "object":
        categorical_col.append(i)
print("categorical columns: ", categorical_col)
print("\n")


numerical_col = []
for i in data.dtypes.index:
    if data.dtypes[i]!="object":
        numerical_col.append(i)
print("numerical columns: ",numerical_col)
# Out:
# categorical columns:  []
#
#
# numerical columns:  ['Wins', 'Runs scored', 'At bat or time at bat', 'base hit', 'second base', 'Triple', 'Home runs', 'Base on balls', 'Strikeout', 'Stolen base', 'Run Average', 'Earned run', 'Earned Run Average', 'Complete Game', 'Shutout', 'Save', 'Errors']

# %% [markdown]
# There is split the data into two parts as we see in this dataset all is numerical columns

# %%
# check the unique values to the data 
data.nunique().to_frame("No. of unique values")
# Out:
#                        No. of unique values
# Wins                                     24
# Runs scored                              28
# At bat or time at bat                    29
# base hit                                 29
# second base                              22
# Triple                                   23
# Home runs                                27
# Base on balls                            29
# Strikeout                                29
# Stolen base                              27
# Run Average                              30
# Earned run                               30
# Earned Run Average                       30
# Complete Game                             9
# Shutout                                  12
# Save                                     20
# Errors                                   21

# %% [markdown]
# There are the inique values present in the dataset

# %% [markdown]
# # Description the dataset

# %%
# statistical summary of numerical dataset 
data.describe()
# Out:
#              Wins  Runs scored  At bat or time at bat     base hit  \
# count   30.000000    30.000000              30.000000    30.000000
# mean    80.966667   688.233333            5516.266667  1403.533333
# std     10.453455    58.761754              70.467372    57.140923
# min     63.000000   573.000000            5385.000000  1324.000000
# 25%     74.000000   651.250000            5464.000000  1363.000000
# 50%     81.000000   689.000000            5510.000000  1382.500000
# 75%     87.750000   718.250000            5570.000000  1451.500000
# max    100.000000   891.000000            5649.000000  1515.000000
#
#        second base     Triple   Home runs  Base on balls   Strikeout  \
# count    30.000000  30.000000   30.000000      30.000000    30.00000
# mean    274.733333  31.300000  163.633333     469.100000  1248.20000
# std      18.095405  10.452355   31.823309      57.053725   103.75947
# min     236.000000  13.000000  100.000000     375.000000   973.00000
# ...

# %% [markdown]
# This gives the statistical information of numericcal columns. The summary of the dataset looks perfect since there is no negative/invalid values present.
#
# The counts of all the columns are smae which means there are no missing values in the dataset.
#
# Here we check the all count mean standard deviation min 25% 50% 75% and max all the dataset.
#
# as i see in this dataset 'base hit', 'home runs', 'base on balls', 'Strikeout', '' columns mean and median of the dataset is different that means here is the skewness present in this dataset.

# %% [markdown]
# #  data visualization

# %%
sns.lmplot(x='Runs scored', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the runs scored

# %%
sns.lmplot(x='At bat or time at bat', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the at bat or time at bat

# %%
sns.lmplot(x='base hit', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the base hit

# %%
sns.lmplot(x='second base', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the second base

# %%
sns.lmplot(x='Triple', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the triple

# %%
sns.lmplot(x='Home runs', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the home runs

# %%
sns.lmplot(x='Base on balls', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation withbase on ball

# %%
sns.lmplot(x='Strikeout', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the strikeout

# %%
sns.lmplot(x='Stolen base', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the stolen base

# %%
sns.lmplot(x='Run Average', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the runs average

# %%
sns.lmplot(x='Earned run', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the Earned run

# %%
sns.lmplot(x='Earned Run Average', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the Earned run Average

# %%
sns.lmplot(x='Complete Game', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the complete game

# %%
sns.lmplot(x='Shutout', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the shutout

# %%
sns.lmplot(x='Save', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the save

# %%
sns.lmplot(x='Errors', y='Wins', data=data, palette='colorblind')

# %% [markdown]
# here as we see wins is totally negative correlation with the errors

# %%
plt.figure(figsize=(25,20))
plotnumber=1
for i in data:
    if plotnumber<=16:
        plt.subplot(5,4,plotnumber)
        sns.regplot(x='Wins', y=i, data=data, color='r')
        plt.xlabel("Wins")
        plt.ylabel(i)
    plotnumber+=1
plt.show()

# %% [markdown]
# Here we visualize the data usign regplot so there is negative correlation target and features data

# %%
plt.figure(figsize = (25, 20), facecolor = 'white')
plotnumber = 1
for col in data:
    if plotnumber<=16:
        ax=plt.subplot(5,4, plotnumber)
        sns.scatterplot(data[col],color = "m")
        plt.xlabel(col, fontsize = 15)
    plotnumber+=1
plt.show()

# %% [markdown]
# Here we visualize the data usign scatterplot so there is negative correlation target and features data

# %%
plt.figure(figsize = (25, 20), facecolor = 'white')
plotnumber = 1
for col in data:
    if plotnumber<=16:
        ax=plt.subplot(5,4, plotnumber)
        sns.distplot(data[col],color = "m")
        plt.xlabel(col, fontsize = 15)
    plotnumber+=1
plt.show()

# %% [markdown]
# Here we visualize the data usign distplot so there is looking the some skewness in the datset

# %%
data.hist(figsize=(25,15))
plt.show()

# %%
plt.figure(figsize=(25,20))
sns.pairplot(data=data, palette = "Dark2")
plt.show()

# %%
plt.figure(figsize = (20,25), facecolor = 'white')
plotnumber = 1
for col in data:
    if plotnumber<=16:
        ax=plt.subplot(5,4, plotnumber)
        sns.boxplot(data[col],color = "m")
        plt.xlabel(col, fontsize = 15)
    plotnumber+=1
plt.show()

# %% [markdown]
# here we check the skewness using boxplot

# %%
plt.figure(figsize = (25, 30), facecolor = 'orange')
plotnumber = 1
for col in data:
    if plotnumber<=16:
        ax=plt.subplot(5,4, plotnumber)
        sns.distplot(data[col],color = "b")
        plt.xlabel(col, fontsize = 15)
    plotnumber+=1
plt.show()

# %% [markdown]
# checking how the data has been distributed in each column using distplot

# %%
data.skew()
# Out:
# Wins                     0.047089
# Runs scored              1.200786
# At bat or time at bat    0.183437
# base hit                 0.670254
# second base             -0.230650
# Triple                   0.129502
# Home runs                0.516441
# Base on balls            0.158498
# Strikeout               -0.156065
# Stolen base              0.479893
# Run Average              0.045734
# Earned run               0.058710
# Earned Run Average       0.053331
# Complete Game            0.736845
# Shutout                  0.565790
# Save                     0.657524
# Errors                   0.890132
# dtype: float64

# %% [markdown]
# check the skewness only found one column is skewed

# %%
data['Runs scored'] = np.cbrt(data['Runs scored'])

# %% [markdown]
# remove the skewness using np.cbrt

# %%
data.skew()
# Out:
# Wins                     0.047089
# Runs scored              0.892970
# At bat or time at bat    0.183437
# base hit                 0.670254
# second base             -0.230650
# Triple                   0.129502
# Home runs                0.516441
# Base on balls            0.158498
# Strikeout               -0.156065
# Stolen base              0.479893
# Run Average              0.045734
# Earned run               0.058710
# Earned Run Average       0.053331
# Complete Game            0.736845
# Shutout                  0.565790
# Save                     0.657524
# Errors                   0.890132
# dtype: float64

# %%
plt.figure(figsize = (25, 30), facecolor = 'orange')
plotnumber = 1
for col in data:
    if plotnumber<=16:
        ax=plt.subplot(5,4, plotnumber)
        sns.distplot(data[col],color = "b")
        plt.xlabel(col, fontsize = 15)
    plotnumber+=1
plt.show()

# %% [markdown]
# Now it look better

# %%
data.corr()
# Out:
#                            Wins  Runs scored  At bat or time at bat  base hit  \
# Wins                   1.000000     0.439027              -0.087947  0.037612
# Runs scored            0.439027     1.000000               0.332282  0.483362
# At bat or time at bat -0.087947     0.332282               1.000000  0.739122
# base hit               0.037612     0.483362               0.739122  1.000000
# second base            0.427797     0.564836               0.453370  0.566847
# Triple                -0.251118    -0.053415               0.435422  0.478694
# Home runs              0.307407     0.675069              -0.066983 -0.090855
# Base on balls          0.484342     0.398238              -0.136414 -0.118281
# Strikeout              0.111850    -0.038776              -0.106022 -0.398830
# Stolen base           -0.157234     0.081242               0.372618  0.413444
# Run Average           -0.812952    -0.048267               0.316010  0.224324
# ...

# %% [markdown]
# Check the correlation

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %% [markdown]
# check the correlation using heatmap

# %%
X = data.drop("Wins", axis=1)
Y = data["Wins"]

# %% [markdown]
# seperating features and target data

# %%
X
# Out:
#     Runs scored  At bat or time at bat  base hit  second base  Triple  \
# 0      8.979377                   5575      1497          300      42
# 1      8.862095                   5467      1349          277      44
# 2      8.745985                   5439      1395          303      29
# 3      8.536178                   5533      1381          260      27
# 4      8.832285                   5605      1515          289      49
# 5      9.622603                   5509      1480          308      17
# 6      9.141787                   5567      1397          272      19
# 7      8.933669                   5485      1370          246      20
# 8      8.635655                   5485      1383          278      32
# 9      9.077520                   5640      1495          294      33
# 10     9.089639                   5511      1419          279      32
# 11     9.000000                   5459      1363          278      26
# ...

# %%
Y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: Wins, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X=pd.DataFrame(scaler.fit_transform(X),columns=X.columns)

# %%
X
# Out:
#     Runs scored  At bat or time at bat  base hit  second base    Triple  \
# 0      0.650959               0.847731  1.663685     1.420173  1.041193
# 1      0.164710              -0.711094 -0.970681     0.127403  1.235809
# 2     -0.316685              -1.115233 -0.151891     1.588795 -0.223808
# 3     -1.186544               0.241522 -0.401088    -0.828122 -0.418423
# 4      0.041117               1.280738  1.984081     0.801892  1.722347
# 5      3.317778              -0.104884  1.361089     1.869832 -1.391501
# 6      1.324315               0.732263 -0.116292    -0.153633 -1.196885
# 7      0.461454              -0.451289 -0.596886    -1.615025 -1.099578
# 8     -0.774111              -0.451289 -0.365489     0.183611  0.068115
# 9      1.057861               1.785913  1.628086     1.082929  0.165423
# 10     1.108108              -0.076017  0.275303     0.239818  0.068115
# 11     0.736464              -0.826562 -0.721484     0.183611 -0.515731
# ...

# %% [markdown]
# Feature scaling using Standard Scalarization

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(X.values, i) for i in range (len(X.columns))]
vif["features"] = X.columns

vif
# Out:
#      VIF values               features
# 0     11.437640            Runs scored
# 1     13.143085  At bat or time at bat
# 2      9.627532               base hit
# 3      4.000069            second base
# 4      3.396196                 Triple
# 5     10.116002              Home runs
# 6      3.793989          Base on balls
# 7      2.592342              Strikeout
# 8      2.119787            Stolen base
# 9    189.997775            Run Average
# 10  1687.916662             Earned run
# 11  1229.666249     Earned Run Average
# 12     3.016584          Complete Game
# 13     3.660828                Shutout
# 14     5.771227                   Save
# 15     2.173231                 Errors

# %% [markdown]
# Check the  Variance Inflation Factor (VIF) so here some columns highly correlated to other columns

# %%
X.drop('Earned Run Average',axis=1,inplace=True)
X.drop('Run Average',axis=1,inplace=True)

# %% [markdown]
# delete some columns who has highly co-releted with other columns

# %% [markdown]
# finding the best random state

# %%
# importing the necessary libraries 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.30, random_state=i)
    
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    
    pred = lr.predict(x_test)
    acc=r2_score(y_test, pred)
    
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is ", maxAccu," on random state ",maxRS)
# Out:
# Maximum r2 score is  0.9527727453628846  on random state  6

# %% [markdown]
# The best accuracy is  0.9527727453628846  on random state  6 usign linearRegression

# %% [markdown]
# Creating train test split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=.30, random_state=maxRS)

# %% [markdown]
# # Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.svm import SVR
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # LinearRegression

# %%
LR = LinearRegression()
LR.fit(x_train, y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print(LR)
print('R2_score:', r2_score(y_test, pred_LR))
print('R2_score on training data:', r2_score(y_train, pred_train)*100)
print('Mean Squared Error:-', mean_squared_error(y_test, pred_LR))
print('Mean Absolute Error:-', mean_absolute_error(y_test, pred_LR))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# LinearRegression()
# R2_score: 0.9527727453628846
# R2_score on training data: 91.89737694531985
# Mean Squared Error:- 5.551826156229788
# Mean Absolute Error:- 2.0717000044001015
# Root Mean Squared Error:- 2.3562313460757176

# %% [markdown]
#  The accurracy for this model is 95 % score using linearRegression

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR, y=y_test, color='r')
plt.plot(pred_LR, pred_LR,color='b')
plt.xlabel('Actual ',fontsize=14)
plt.ylabel('Predicted ',fontsize=14)
plt.title("Linear Regression ", fontsize=18)
plt.show()

# %% [markdown]
# Predict the model using scatter plot so here looks good after removing the skewness and outliers

# %% [markdown]
# # RandomForestRegressor

# %%
RFR = RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print(RFR)
print('R2_score:', r2_score(y_test, pred_RFR))
print('R2_score on training data:', r2_score(y_train, pred_train)*100)
print('Mean Squared Error:-', mean_squared_error(y_test, pred_RFR))
print('Mean Absolute Error:-', mean_absolute_error(y_test, pred_RFR))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# RandomForestRegressor()
# R2_score: 0.613309168241966
# R2_score on training data: 92.72096951581254
# Mean Squared Error:- 45.45765555555554
# Mean Absolute Error:- 5.545555555555556
# Root Mean Squared Error:- 6.742229271951195

# %% [markdown]
# The accurracy for this model is 61 % using RandomForestRegressor

# %% [markdown]
# # KNN

# %%
knn = KNN()
knn.fit(x_train, y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print(knn)
print('R2_score:', r2_score(y_test, pred_knn))
print('R2_score on training data:', r2_score(y_train, pred_train)*100)
print('Mean Squared Error:-', mean_squared_error(y_test, pred_knn))
print('Mean Absolute Error:-', mean_absolute_error(y_test, pred_knn))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# KNeighborsRegressor()
# R2_score: 0.5989792060491492
# R2_score on training data: 60.47633824670289
# Mean Squared Error:- 47.14222222222224
# Mean Absolute Error:- 5.355555555555558
# Root Mean Squared Error:- 6.866019386968132

# %% [markdown]
# The accurracy for this model is 59 % using KNN

# %% [markdown]
# # GradientBoostingRegressor

# %%
GBR = GradientBoostingRegressor()
GBR.fit(x_train, y_train)
pred_GBR = GBR.predict(x_test)
pred_train = GBR.predict(x_train)
print(GBR)
print('R2_score:', r2_score(y_test, pred_GBR))
print('R2_score on training data:', r2_score(y_train, pred_train)*100)
print('Mean Squared Error:-', mean_squared_error(y_test, pred_GBR))
print('Mean Absolute Error:-', mean_absolute_error(y_test, pred_GBR))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# GradientBoostingRegressor()
# R2_score: 0.639716069653524
# R2_score on training data: 99.99998898047062
# Mean Squared Error:- 42.35337758961907
# Mean Absolute Error:- 5.351425348016913
# Root Mean Squared Error:- 6.507947263893514

# %% [markdown]
# The accurracy for this model is 64 % using GradientBoostingRegressor

# %% [markdown]
# # Lasso

# %%
lasso = Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print(lasso)
print('R2_score:', r2_score(y_test, pred_lasso))
print('R2_score on training data:', r2_score(y_train, pred_train)*100)
print('Mean Squared Error:-', mean_squared_error(y_test, pred_lasso))
print('Mean Absolute Error:-', mean_absolute_error(y_test, pred_lasso))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# Lasso()
# R2_score: 0.832882750533411
# R2_score on training data: 85.5289876996469
# Mean Squared Error:- 19.645561103961242
# Mean Absolute Error:- 3.813497129303043
# Root Mean Squared Error:- 4.43233133959559

# %% [markdown]
# The accurracy for this model is 83 % using lasso

# %% [markdown]
# # Ridge

# %%
rd = Ridge()
rd.fit(x_train, y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print(rd)
print('R2_score:', r2_score(y_test, pred_rd))
print('R2_score on training data:', r2_score(y_train, pred_train)*100)
print('Mean Squared Error:-', mean_squared_error(y_test, pred_rd))
print('Mean Absolute Error:-', mean_absolute_error(y_test, pred_rd))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# Ridge()
# R2_score: 0.9528977500964797
# R2_score on training data: 90.80641502754526
# Mean Squared Error:- 5.53713115532494
# Mean Absolute Error:- 1.820399145182994
# Root Mean Squared Error:- 2.3531109526167566

# %% [markdown]
# The accurracy for this model is 95 % using ridge

# %% [markdown]
# # DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)
pred_dt =dt.predict(x_test)
pred_train = dt.predict(x_train)
print(dt)
print('R2_score:', r2_score(y_test, pred_dt))
print('R2_score on training data:', r2_score(y_train, pred_train)*100)
print('Mean Squared Error:-', mean_squared_error(y_test, pred_dt))
print('Mean Absolute Error:-', mean_absolute_error(y_test, pred_dt))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_dt)))
# Out:
# DecisionTreeRegressor()
# R2_score: 0.555765595463138
# R2_score on training data: 100.0
# Mean Squared Error:- 52.22222222222222
# Mean Absolute Error:- 6.0
# Root Mean Squared Error:- 7.2264944628929335

# %% [markdown]
# The accurracy for this model is 62 % using DecisionTreeRegressor

# %% [markdown]
# # SVR

# %%
svr= SVR()
svr.fit(x_train, y_train)
pred_svr =svr.predict(x_test)
pred_train = svr.predict(x_train)
print(svr)
print('R2_score:', r2_score(y_test, pred_svr))
print('R2_score on training data:', r2_score(y_train, pred_train)*100)
print('Mean Squared Error:-', mean_squared_error(y_test, pred_svr))
print('Mean Absolute Error:-', mean_absolute_error(y_test, pred_svr))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# SVR()
# R2_score: 0.04488072094337048
# R2_score on training data: 22.104946467731313
# Mean Squared Error:- 112.27957747132378
# Mean Absolute Error:- 8.974488336760897
# Root Mean Squared Error:- 10.596205805443937

# %% [markdown]
# The accurracy for this model is 04 % using SVR support vector regressor

# %% [markdown]
# # ExtraTreesRegressor

# %%
etr= ExtraTreesRegressor()
etr.fit(x_train, y_train)
pred_etr =etr.predict(x_test)
pred_train = etr.predict(x_train)
print(etr)
print('R2_score:', r2_score(y_test, pred_etr))
print('R2_score on training data:', r2_score(y_train, pred_train)*100)
print('Mean Squared Error:-', mean_squared_error(y_test, pred_etr))
print('Mean Absolute Error:-', mean_absolute_error(y_test, pred_etr))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# ExtraTreesRegressor()
# R2_score: 0.47051493383742893
# R2_score on training data: 100.0
# Mean Squared Error:- 62.24391111111114
# Mean Absolute Error:- 6.404444444444445
# Root Mean Squared Error:- 7.889481041938763

# %% [markdown]
# The accurracy for this model is 43 % using ExtraTreesRegressor

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(LR, X,Y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is -",(r2_score(y_test,pred_LR) - score.mean())*100)
# Out:
# [ 0.66956174 -0.78584966  0.53429901  0.6722854   0.77203168]
# 0.37246563473565736
# Difference between R2 score and cross validation score is - 58.03071106272273

# %%
score1 = cross_val_score(RFR, X,Y)
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation score is -",(r2_score(y_test,pred_RFR) - score1.mean())*100)
# Out:
# [ 0.3663968  -5.27098015  0.17203679  0.5046724   0.76738195]
# -0.6920984418593988
# Difference between R2 score and cross validation score is - 130.54076101013646

# %%
score2 = cross_val_score(knn, X,Y)
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation score is -",(r2_score(y_test,pred_knn) - score2.mean())*100)
# Out:
# [ 0.21072824 -2.62748092  0.19961919  0.32920565  0.53313609]
# -0.2709583471226121
# Difference between R2 score and cross validation score is - 86.99375531717612

# %%
score3 = cross_val_score(GBR, X,Y)
print(score3)
print(score3.mean())
print("Difference between R2 score and cross validation score is -",(r2_score(y_test,pred_GBR) - score3.mean())*100)
# Out:
# [ 0.26013889 -7.12571803  0.19868151  0.74405762  0.54108395]
# -1.0763512117670075
# Difference between R2 score and cross validation score is - 171.60672814205316

# %%
score4 = cross_val_score(lasso, X,Y)
print(score4)
print(score4.mean())
print("Difference between R2 score and cross validation score is -",(r2_score(y_test,pred_lasso) - score4.mean())*100)
# Out:
# [ 0.77625189 -0.39589162  0.70270318  0.67967344  0.91596298]
# 0.5357399758698295
# Difference between R2 score and cross validation score is - 29.71427746635815

# %%
score5 = cross_val_score(rd, X,Y)
print(score5)
print(score5.mean())
print("Difference between R2 score and cross validation score is -",(r2_score(y_test,pred_rd) - score5.mean())*100)
# Out:
# [ 0.68663621 -1.06746786  0.57757889  0.75354475  0.89769267]
# 0.36959693286839174
# Difference between R2 score and cross validation score is - 58.3300817228088

# %%
score6 = cross_val_score(dt, X,Y)
print(score6)
print(score6.mean())
print("Difference between R2 score and cross validation score is -",(r2_score(y_test,pred_dt) - score6.mean())*100)
# Out:
# [-0.48934281 -9.09923664 -0.35491241  0.33124019  0.0147929 ]
# -1.9194917548285424
# Difference between R2 score and cross validation score is - 247.525735029168

# %%
score7 = cross_val_score(svr, X,Y)
print(score7)
print(score7.mean())
print("Difference between R2 score and cross validation score is -",(r2_score(y_test,pred_svr) - score7.mean())*100)
# Out:
# [-0.14598377 -0.80176298 -0.28332251 -0.63367996 -0.05163691]
# -0.3832772248230862
# Difference between R2 score and cross validation score is - 42.815794576645665

# %%
score8 = cross_val_score(etr, X,Y)
print(score8)
print(score8.mean())
print("Difference between R2 score and cross validation score is -",(r2_score(y_test,pred_etr) - score8.mean())*100)
# Out:
# [-0.14484956 -3.86859924  0.40012487  0.39588816  0.74135243]
# -0.49521666731464736
# Difference between R2 score and cross validation score is - 96.57316011520763

# %% [markdown]
# From the difference of both R2 score and cross validation score computed on R2 score we can conclude that Lasso regression as our best finding and best performing model.

# %% [markdown]
# # Hyper parameter tuning

# %%
param={'alpha':[1.0,.05,.04,2],'fit_intercept':[True,False],
      'max_iter':[500,700,800,9800,1000],
      'positive':[False,True],
      'random_state':[1,4,10,20]
      
      }
lasso=Lasso()
gscv=GridSearchCV(lasso,param,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1.0, 0.05, 0.04, 2],
#                          'fit_intercept': [True, False],
#                          'max_iter': [500, 700, 800, 9800, 1000],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20]})

# %%
gscv.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': True,
#  'max_iter': 500,
#  'positive': False,
#  'random_state': 1}

# %%
Model=Lasso(alpha=1.0, fit_intercept = True, positive= False, random_state= 1, max_iter=500)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print('R2_score:', r2_score(y_test, pred))
print('Mean Squared Error:-', mean_squared_error(y_test, pred))
print('Mean Absolute Error:-', mean_absolute_error(y_test, pred))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.832882750533411
# Mean Squared Error:- 19.645561103961242
# Mean Absolute Error:- 3.813497129303043
# Root Mean Squared Error:- 4.43233133959559

# %% [markdown]
# we take the predicted parameter which have model predict

# %%
Model1=Lasso(alpha=.05, fit_intercept = True, positive= False, random_state= 1, max_iter=800)

# %%
Model1.fit(x_train,y_train)
pred=Model1.predict(x_test)
print('R2_score:', r2_score(y_test, pred))
print('Mean Squared Error:-', mean_squared_error(y_test, pred))
print('Mean Absolute Error:-', mean_absolute_error(y_test, pred))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.9646641744875314
# Mean Squared Error:- 4.153922599132415
# Mean Absolute Error:- 1.7818697880621006
# Root Mean Squared Error:- 2.0381174154430886

# %% [markdown]
# Here we take our own parameter

# %% [markdown]
# # Save the model

# %%
import pickle
filename='Baseball_case_study.pkl'
pickle.dump(Model1,open(filename,'wb'))

# %%
load = pickle.load(open('Baseball_case_study.pkl','rb'))
result = load.score(x_test, y_test)
print(result*100)
# Out:
# 96.46641744875313

# %% [markdown]
# # Predicting the save model

# %%
conclusion = pd.DataFrame([load.predict(x_test)[:], y_test[:]],index=["predicted","original"])
conclusion
# Out:
#                    0          1          2          3          4          5  \
# predicted  92.321437  74.451047  81.376261  88.946499  93.317014  65.881841
# original   95.000000  74.000000  79.000000  87.000000  97.000000  64.000000
#
#                    6          7          8
# predicted  82.536038  93.686849  70.203256
# original   81.000000  93.000000  71.000000

# %% [markdown]
# steps:- first import the necessary libraries
# Then read the data , Then perform the EDA preprocessing, feature engineering , then split the data into two parts first is target and one is features variables, then train and test the data using train test split, then build the different different models , and then check the performance of different different model, then check the cross validation score of different different model then find the best models in all the models then do hyperparameter tuning for choosing the best then save the model
